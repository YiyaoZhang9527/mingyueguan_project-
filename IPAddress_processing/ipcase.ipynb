# %%
import re
import ipaddress
import pandas as pd

def is_valid_ip_address(address):
    """
    Validates IPv4 addresses.
    验证ipv4地址是否合法
    Args:
        address (str): A string, the IPv4 address.
    """
    try:
        ipaddress.ip_address(address)
        return True
    except ValueError:
        return False
    

is_valid_ip_address("fe80::ce81:b1c:bd2c:69e"),is_valid_ip_address("0:0:0:0:0:0"),is_valid_ip_address("255.255.255.255"),is_valid_ip_address("0.0.0.0"),is_valid_ip_address("a4:83:e7:1e:0f:84")
# Out:
# (True, False, True, True, False)

# %%
import os
ipv4_case_path = os.path.expanduser('~/mingyueguan_project/IPAddress_processing/ipv4casefile.txt')
ipv4_case_file = [re.sub(r"^[\w\s]",'',line).strip('\n').replace("'",'').replace(",",'') for line in open(ipv4_case_path, 'r').readlines()]
{ipv4:is_valid_ip_address(ipv4) for ipv4 in ipv4_case_file}
# Out:
# {'106.75.17.82': True,
#  '113.204.147.26': True,
#  '114.142.251.150': True,
#  '116.236.115.171': True,
#  '122.172.216.150': True,
#  '123.168.49.122': True,
#  '174.58.12.135': True,
#  '177.36.70.102': True,
#  '177.36.70.35': True,
#  '178.219.118.207': True,
#  '178.79.148.229': True,
#  '182.19.172.166': True,
#  '186.179.100.109': True,
#  '186.200.91.70': True,
#  '190.182.179.76': True,
#  '193.176.215.250': True,
#  '195.242.233.157': True,
#  '200.205.226.154': True,
#  '200.26.234.184': True,
#  '20.201.116.153': True,
#  '221.7.131.202': True,
#  '5.152.239.35': True,
#  '58.153.44.47': True,
#  '64.225.17.240': True,
#  '68.37.71.89': True,
#  '78.89.152.191': True,
#  '81.89.79.166': True,
#  '82.154.63.218': True,
#  '83.172.28.164': True,
#  '91.121.40.244': True,
#  '96.83.219.37': True,
#  '96.90.7.195': True,
#  'Mon': False,
#  'Sat': False,
#  'Wed': False,
#  '101.109.253.90': True,
#  '103.153.22.59': True,
#  '103.162.89.254': True,
# ...

# %%
import ipaddress

#ip_address('114.132.213.157').is_reserved,ip_address('fe80::ee:2915:95b2:ce7d').is_private

def is_private(IPAddress):
    """
    是否是私有地址
    """
    vaild_ip = ipaddress.ip_address(IPAddress)
    if vaild_ip.is_private:
        if vaild_ip.is_private:
            return True
        else:
            return False
    return ValueError('IPAddress is not a valid IPv4 or IPv6 address')

def ip_puvlic(IPAddress):
    """
    是否是公共地址
    """
    vaild_ip = ipaddress.ip_address(IPAddress)
    if vaild_ip.is_private:
        vaild_private_ip = ipaddress.ip_address(IPAddress)
        if vaild_private_ip:
            return False
        else:
            return True
    return ValueError('IPAddress is not a valid IPv4 or IPv6 address')
    

ip_puvlic('114.132.213.157') == True
# Out:
# False

# %%
case_ipv6 = """
lo0: flags=8049<UP,LOOPBACK,RUNNING,MULTICAST> mtu 16384
	options=1203<RXCSUM,TXCSUM,TXSTATUS,SW_TIMESTAMP>
	inet 127.0.0.1 netmask 0xff000000 
	inet6 ::1 prefixlen 128 
	inet6 fe80::1%lo0 prefixlen 64 scopeid 0x1 
	nd6 options=201<PERFORMNUD,DAD>
gif0: flags=8010<POINTOPOINT,MULTICAST> mtu 1280
stf0: flags=0<> mtu 1280
ap1: flags=8802<BROADCAST,SIMPLEX,MULTICAST> mtu 1500
	options=400<CHANNEL_IO>
	ether a6:83:e7:1e:0f:84 
	media: autoselect
	status: inactive
en0: flags=8863<UP,BROADCAST,SMART,RUNNING,SIMPLEX,MULTICAST> mtu 1500
	options=6463<RXCSUM,TXCSUM,TSO4,TSO6,CHANNEL_IO,PARTIAL_CSUM,ZEROINVERT_CSUM>
	ether a4:83:e7:1e:0f:84 
	inet6 fe80::ee:2915:95b2:ce7d%en0 prefixlen 64 secured scopeid 0x5 
	inet 192.168.2.9 netmask 0xffffff00 broadcast 192.168.2.255
	nd6 options=201<PERFORMNUD,DAD>
	media: autoselect
	status: active
awdl0: flags=8943<UP,BROADCAST,RUNNING,PROMISC,SIMPLEX,MULTICAST> mtu 1500
	options=400<CHANNEL_IO>
	ether f6:ad:e3:b8:e9:0e 
	inet6 fe80::f4ad:e3ff:feb8:e90e%awdl0 prefixlen 64 scopeid 0x6 
	nd6 options=201<PERFORMNUD,DAD>
	media: autoselect
	status: active
bridge0: flags=8863<UP,BROADCAST,SMART,RUNNING,SIMPLEX,MULTICAST> mtu 1500
	options=63<RXCSUM,TXCSUM,TSO4,TSO6>
	ether 82:95:1e:c0:2c:01 
	Configuration:
		id 0:0:0:0:0:0 priority 0 hellotime 0 fwddelay 0
		maxage 0 holdcnt 0 proto stp maxaddr 100 timeout 1200
		root id 0:0:0:0:0:0 priority 0 ifcost 0 port 0
		ipfilter disabled flags 0x0
	member: en1 flags=3<LEARNING,DISCOVER>
	        ifmaxaddr 0 port 10 priority 0 path cost 0
	member: en2 flags=3<LEARNING,DISCOVER>
	        ifmaxaddr 0 port 12 priority 0 path cost 0
	member: en3 flags=3<LEARNING,DISCOVER>
	        ifmaxaddr 0 port 9 priority 0 path cost 0
	member: en4 flags=3<LEARNING,DISCOVER>
	        ifmaxaddr 0 port 11 priority 0 path cost 0
	nd6 options=201<PERFORMNUD,DAD>
	media: <unknown type>
	status: inactive
llw0: flags=8863<UP,BROADCAST,SMART,RUNNING,SIMPLEX,MULTICAST> mtu 1500
	options=400<CHANNEL_IO>
	ether f6:ad:e3:b8:e9:0e 
	inet6 fe80::f4ad:e3ff:feb8:e90e%llw0 prefixlen 64 scopeid 0x8 
	nd6 options=201<PERFORMNUD,DAD>
	media: autoselect
	status: active
en3: flags=8963<UP,BROADCAST,SMART,RUNNING,PROMISC,SIMPLEX,MULTICAST> mtu 1500
	options=460<TSO4,TSO6,CHANNEL_IO>
	ether 82:95:1e:c0:2c:05 
	media: autoselect <full-duplex>
	status: inactive
en1: flags=8963<UP,BROADCAST,SMART,RUNNING,PROMISC,SIMPLEX,MULTICAST> mtu 1500
	options=460<TSO4,TSO6,CHANNEL_IO>
	ether 82:95:1e:c0:2c:01 
	media: autoselect <full-duplex>
	status: inactive
en4: flags=8963<UP,BROADCAST,SMART,RUNNING,PROMISC,SIMPLEX,MULTICAST> mtu 1500
	options=460<TSO4,TSO6,CHANNEL_IO>
	ether 82:95:1e:c0:2c:04 
	media: autoselect <full-duplex>
	status: inactive
en2: flags=8963<UP,BROADCAST,SMART,RUNNING,PROMISC,SIMPLEX,MULTICAST> mtu 1500
	options=460<TSO4,TSO6,CHANNEL_IO>
	ether 82:95:1e:c0:2c:00 
	media: autoselect <full-duplex>
	status: inactive
en6: flags=8863<UP,BROADCAST,SMART,RUNNING,SIMPLEX,MULTICAST> mtu 1500
	ether ac:de:48:00:11:22 
	inet6 fe80::aede:48ff:fe00:1122%en6 prefixlen 64 scopeid 0xd 
	nd6 options=201<PERFORMNUD,DAD>
	media: autoselect (100baseTX <full-duplex>)
	status: active
utun0: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1380
	inet6 fe80::275e:4b48:8c2c:63ed%utun0 prefixlen 64 scopeid 0xe 
	nd6 options=201<PERFORMNUD,DAD>
utun1: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 2000
	inet6 fe80::8b7c:5223:7924:b11f%utun1 prefixlen 64 scopeid 0xf 
	nd6 options=201<PERFORMNUD,DAD>
utun2: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1000
	inet6 fe80::ce81:b1c:bd2c:69e%utun2 prefixlen 64 scopeid 0x10 
	nd6 options=201<PERFORMNUD,DAD>
utun3: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1380
	inet6 fe80::74e8:eed1:db71:18fd%utun3 prefixlen 64 scopeid 0x11 
	nd6 options=201<PERFORMNUD,DAD>
utun4: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1380
	inet6 fe80::7a54:4f5d:bad9:9c50%utun4 prefixlen 64 scopeid 0x12 
	nd6 options=201<PERFORMNUD,DAD>
utun5: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1380
	inet6 fe80::261a:7e91:fd89:e4dc%utun5 prefixlen 64 scopeid 0x13 
	nd6 options=201<PERFORMNUD,DAD>
utun6: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1380
	inet6 fe80::553c:7cc1:6e91:6a3e%utun6 prefixlen 64 scopeid 0x14 
	nd6 options=201<PERFORMNUD,DAD>
utun7: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1380
	inet6 fe80::7658:63d1:b7c6:495d%utun7 prefixlen 64 scopeid 0x15 
	nd6 options=201<PERFORMNUD,DAD>
utun8: flags=8051<UP,POINTOPOINT,RUNNING,MULTICAST> mtu 1380
	inet6 fe80::b912:1f28:6aa4:7cd9%utun8 prefixlen 64 scopeid 0x16 
	nd6 options=201<PERFORMNUD,DAD>

"""

# %%
# ipv6_pattern = re.compile(
#     """
# (
# ([0-9a-fA-F]{1,4}:){7,7}[0-9a-fA-F]{1,4}|          # 1:2:3:4:5:6:7:8
# ([0-9a-fA-F]{1,4}:){1,7}:|                         # 1::                              1:2:3:4:5:6:7::
# ([0-9a-fA-F]{1,4}:){1,6}:[0-9a-fA-F]{1,4}|         # 1::8             1:2:3:4:5:6::8  1:2:3:4:5:6::8
# ([0-9a-fA-F]{1,4}:){1,5}(:[0-9a-fA-F]{1,4}){1,2}|  # 1::7:8           1:2:3:4:5::7:8  1:2:3:4:5::8
# ([0-9a-fA-F]{1,4}:){1,4}(:[0-9a-fA-F]{1,4}){1,3}|  # 1::6:7:8         1:2:3:4::6:7:8  1:2:3:4::8
# ([0-9a-fA-F]{1,4}:){1,3}(:[0-9a-fA-F]{1,4}){1,4}|  # 1::5:6:7:8       1:2:3::5:6:7:8  1:2:3::8
# ([0-9a-fA-F]{1,4}:){1,2}(:[0-9a-fA-F]{1,4}){1,5}|  # 1::4:5:6:7:8     1:2::4:5:6:7:8  1:2::8
# [0-9a-fA-F]{1,4}:((:[0-9a-fA-F]{1,4}){1,6})|       # 1::3:4:5:6:7:8   1::3:4:5:6:7:8  1::8  
# :((:[0-9a-fA-F]{1,4}){1,7}|:)|                     # ::2:3:4:5:6:7:8  ::2:3:4:5:6:7:8 ::8       ::     
# fe80:(:[0-9a-fA-F]{0,4}){0,4}%[0-9a-zA-Z]{1,}|     # fe80::7:8%eth0   fe80::7:8%1     (link-local IPv6 addresses with zone index)
# ::(ffff(:0{1,4}){0,1}:){0,1}
# ((25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])\.){3,3}
# (25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])|          # ::255.255.255.255   ::ffff:255.255.255.255  ::ffff:0:255.255.255.255  (IPv4-mapped IPv6 addresses and IPv4-translated addresses)
# ([0-9a-fA-F]{1,4}:){1,4}:
# ((25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])\.){3,3}
# (25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])           # 2001:db8:3:4::192.0.2.33  64:ff9b::192.0.2.33 (IPv4-Embedded IPv6 Address)
# )
# """, re.VERBOSE)


    # ipv6_pattern = re.compile(
    #     '''(([0-9a-fA-F]{1,4}:){7,7}[0-9a-fA-F]{1,4}|
    #     ([0-9a-fA-F]{1,4}:){1,7}:|([0-9a-fA-F]{1,4}:)
    #     {1,6}:[0-9a-fA-F]{1,4}|([0-9a-fA-F]{1,4}:){1
    #     ,5}(:[0-9a-fA-F]{1,4}){1,2}|([0-9a-fA-F]{1,4}
    #     :){1,4}(:[0-9a-fA-F]{1,4}){1,3}|([0-9a-fA-F]{
    #     1,4}:){1,3}(:[0-9a-fA-F]{1,4}){1,4}|([0-9a-fA
    #     -F]{1,4}:){1,2}(:[0-9a-fA-F]{1,4}){1,5}|[0-9a
    #     -fA-F]{1,4}:((:[0-9a-fA-F]{1,4}){1,6})|:((:[0
    #     -9a-fA-F]{1,4}){1,7}|:)|fe80:(:[0-9a-fA-F]{0,
    #     4}){0,4}%[0-9a-zA-Z]{1,}|::(ffff(:0{1,4}){0,1}
    #     :){0,1}((25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9
    #     ])\.){3,3}(25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0
    #     -9])|([0-9a-fA-F]{1,4}:){1,4}:((25[0-5]|(2[0-4]
    #     |1{0,1}[0-9]){0,1}[0-9])\.){3,3}(25[0-5]|(2[0-4]
    #     |1{0,1}[0-9]){0,1}[0-9]))'''
    #     , re.VERBOSE)
    
#     ipv6_pattern = re.compile(
#         """
#         (
# ([0-9a-fA-F]{1,4}:){7,7}[0-9a-fA-F]{1,4}|          # 1:2:3:4:5:6:7:8
# ([0-9a-fA-F]{1,4}:){1,7}:|                         # 1::                              1:2:3:4:5:6:7::
# ([0-9a-fA-F]{1,4}:){1,6}:[0-9a-fA-F]{1,4}|         # 1::8             1:2:3:4:5:6::8  1:2:3:4:5:6::8
# ([0-9a-fA-F]{1,4}:){1,5}(:[0-9a-fA-F]{1,4}){1,2}|  # 1::7:8           1:2:3:4:5::7:8  1:2:3:4:5::8
# ([0-9a-fA-F]{1,4}:){1,4}(:[0-9a-fA-F]{1,4}){1,3}|  # 1::6:7:8         1:2:3:4::6:7:8  1:2:3:4::8
# ([0-9a-fA-F]{1,4}:){1,3}(:[0-9a-fA-F]{1,4}){1,4}|  # 1::5:6:7:8       1:2:3::5:6:7:8  1:2:3::8
# ([0-9a-fA-F]{1,4}:){1,2}(:[0-9a-fA-F]{1,4}){1,5}|  # 1::4:5:6:7:8     1:2::4:5:6:7:8  1:2::8
# [0-9a-fA-F]{1,4}:((:[0-9a-fA-F]{1,4}){1,6})|       # 1::3:4:5:6:7:8   1::3:4:5:6:7:8  1::8  
# :((:[0-9a-fA-F]{1,4}){1,7}|:)|                     # ::2:3:4:5:6:7:8  ::2:3:4:5:6:7:8 ::8       ::     
# fe80:(:[0-9a-fA-F]{0,4}){0,4}%[0-9a-zA-Z]{1,}|     # fe80::7:8%eth0   fe80::7:8%1     (link-local IPv6 addresses with zone index)
# ::(ffff(:0{1,4}){0,1}:){0,1}
# ((25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])\.){3,3}
# (25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])|          # ::255.255.255.255   ::ffff:255.255.255.255  ::ffff:0:255.255.255.255  (IPv4-mapped IPv6 addresses and IPv4-translated addresses)
# ([0-9a-fA-F]{1,4}:){1,4}:
# ((25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])\.){3,3}
# (25[0-5]|(2[0-4]|1{0,1}[0-9]){0,1}[0-9])           # 2001:db8:3:4::192.0.2.33  64:ff9b::192.0.2.33 (IPv4-Embedded IPv6 Address)
# )
#         """
#     ,re.VERBOSE)
    
    # IPV4SEG  = r'(?:25[0-5]|(?:2[0-4]|1{0,1}[0-9]){0,1}[0-9])'
    # IPV4ADDR = r'(?:(?:' + IPV4SEG + r'\.){3,3}' + IPV4SEG + r')'
    # IPV6SEG  = r'(?:(?:[0-9a-fA-F]){1,4})'
    # IPV6GROUPS = (
    #     r'(?:' + IPV6SEG + r':){7,7}' + IPV6SEG,                  # 1:2:3:4:5:6:7:8
    #     r'(?:' + IPV6SEG + r':){1,7}:',                           # 1::                                 1:2:3:4:5:6:7::
    #     r'(?:' + IPV6SEG + r':){1,6}:' + IPV6SEG,                 # 1::8               1:2:3:4:5:6::8   1:2:3:4:5:6::8
    #     r'(?:' + IPV6SEG + r':){1,5}(?::' + IPV6SEG + r'){1,2}',  # 1::7:8             1:2:3:4:5::7:8   1:2:3:4:5::8
    #     r'(?:' + IPV6SEG + r':){1,4}(?::' + IPV6SEG + r'){1,3}',  # 1::6:7:8           1:2:3:4::6:7:8   1:2:3:4::8
    #     r'(?:' + IPV6SEG + r':){1,3}(?::' + IPV6SEG + r'){1,4}',  # 1::5:6:7:8         1:2:3::5:6:7:8   1:2:3::8
    #     r'(?:' + IPV6SEG + r':){1,2}(?::' + IPV6SEG + r'){1,5}',  # 1::4:5:6:7:8       1:2::4:5:6:7:8   1:2::8
    #     IPV6SEG + r':(?:(?::' + IPV6SEG + r'){1,6})',             # 1::3:4:5:6:7:8     1::3:4:5:6:7:8   1::8
    #     r':(?:(?::' + IPV6SEG + r'){1,7}|:)',                     # ::2:3:4:5:6:7:8    ::2:3:4:5:6:7:8  ::8       ::
    #     r'fe80:(?::' + IPV6SEG + r'){0,4}%[0-9a-zA-Z]{1,}',       # fe80::7:8%eth0     fe80::7:8%1  (link-local IPv6 addresses with zone index)
    #     r'::(?:ffff(?::0{1,4}){0,1}:){0,1}[^\s:]' + IPV4ADDR,     # ::255.255.255.255  ::ffff:255.255.255.255  ::ffff:0:255.255.255.255 (IPv4-mapped IPv6 addresses and IPv4-translated addresses)
    #     r'(?:' + IPV6SEG + r':){1,4}:[^\s:]' + IPV4ADDR,          # 2001:db8:3:4::192.0.2.33  64:ff9b::192.0.2.33 (IPv4-Embedded IPv6 Address)
    # re.I)
    # ipv6_pattern = '|'.join(['(?:{})'.format(g) for g in IPV6GROUPS[::-1]])  # Reverse rows for greedy match
    
    #pv6_pattern = re.compile(r"([a-f0-9:]+:+)+[a-f0-9]+",re.I)
    
    #ipv6_pattern = re.compile(r'\A(?:(?:\w{1,7})?)(?::(?:\w{1,7})?){5}')
    
string_IPv6="inet6 fe80::275e:4b48:8c2c:63ed%utun0 prefixlen 64 scopeid 0xe 1050:0:0:0:5:600:300c:326b"



# list(filter(lambda x: len(x[0]) > 20, re.findall(ipv6_pattern, string_IPv6)))

# %%
def regex_get_Ipv6(string,return_error=False):
    """
    汉语注释：提取并验证IPv4地址
    ENGLISH COMMENT: Extract and validate IPv4 address
    """
    threshold_value = 3
    result = []
    error_list = []
    
    
    # TODO: IPv6 address
    # ipv6_pattern = re.compile(r"(?:(?:[\da-fA-F]{1,4}\:){6}(?:[\da-fA-F]{1,4}\:[\da-fA-F]{1,4}|(?:(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)))|\:\:(?:[\da-fA-F]{1,4}\:){5}(?:[\da-fA-F]{1,4}\:[\da-fA-F]{1,4}|(?:(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)))|(?:[\da-fA-F]{1,4})?\:\:(?:[\da-fA-F]{1,4}\:){4}(?:[\da-fA-F]{1,4}\:[\da-fA-F]{1,4}|(?:(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)))|(?:(?:[\da-fA-F]{1,4}\:){0,1}[\da-fA-F]{1,4})?\:\:(?:[\da-fA-F]{1,4}\:){3}(?:[\da-fA-F]{1,4}\:[\da-fA-F]{1,4}|(?:(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)))|(?:(?:[\da-fA-F]{1,4}\:){0,2}[\da-fA-F]{1,4})?\:\:(?:[\da-fA-F]{1,4}\:){2}(?:[\da-fA-F]{1,4}\:[\da-fA-F]{1,4}|(?:(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)))|(?:(?:[\da-fA-F]{1,4}\:){0,3}[\da-fA-F]{1,4})?\:\:(?:[\da-fA-F]{1,4}\:)(?:[\da-fA-F]{1,4}\:[\da-fA-F]{1,4}|(?:(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)))|(?:(?:[\da-fA-F]{1,4}\:){0,4}[\da-fA-F]{1,4})?\:\:(?:[\da-fA-F]{1,4}\:[\da-fA-F]{1,4}|(?:(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)\.(?:25[0-5]|2[0-4]\d|1\d\d|[1-9]\d|\d)))|(?:(?:[\da-fA-F]{1,4}\:){0,5}[\da-fA-F]{1,4})?\:\:[\da-fA-F]{1,4}|(?:(?:[\da-fA-F]{1,4}\:){0,6}[\da-fA-F]{1,4})?\:\:)")
    
    ipv6_pattern = re.compile(r'(([a-f0-9:]+:+)+[a-f0-9]+)')
    find_ipv6 = re.findall(ipv6_pattern, string)
    # print(find_ipv6)
    for elem in find_ipv6:
        if len(elem[0]) > threshold_value:
            string_IPv6 = list(filter(lambda x : len(x)>threshold_value ,elem))[0] 
            if is_valid_ip_address(string_IPv6):
                result.append(string_IPv6)
            else:
                error_list.append(string_IPv6)
    if return_error:
        return result, error_list
    return result

# %%
regex_get_Ipv6(case_ipv6)
# Out:
# ['fe80::1',
#  'fe80::ee:2915:95b2:ce7d',
#  'fe80::f4ad:e3ff:feb8:e90e',
#  'fe80::f4ad:e3ff:feb8:e90e',
#  'fe80::aede:48ff:fe00:1122',
#  'fe80::275e:4b48:8c2c:63ed',
#  'fe80::8b7c:5223:7924:b11f',
#  'fe80::ce81:b1c:bd2c:69e',
#  'fe80::74e8:eed1:db71:18fd',
#  'fe80::7a54:4f5d:bad9:9c50',
#  'fe80::261a:7e91:fd89:e4dc',
#  'fe80::553c:7cc1:6e91:6a3e',
#  'fe80::7658:63d1:b7c6:495d',
#  'fe80::b912:1f28:6aa4:7cd9']

# %%
is_valid_ip_address('0:0:0:0:0:0')
# Out:
# False

# %%
#!/usr/bin/env python
# -*- encoding: utf-8 -*-
'''
@File    :   IP_log.py
@Time    :   2020/09/04 13:26:35
@Author  :   ManmanZhang
@Version :   1.0
@Contact :   408903228@qq.com
@Desc    :   None
'''

# here put the import lib
import os
import geoip2.database
import subprocess
import pandas as pd
from tqdm import tqdm
import time
#from config import ipv4_query_dataset_from_ipapi,ipv4_query_log_from_ipapi,dataset_path_of_city,headers_of_ipv4_query_log_from_ipapi
#from file_manager import init_paths_for_jarvis
#init_paths_for_jarvis(ipv4_query_log_from_ipapi)
dataset_path_of_city = "/Users/magu/mingyueguan_project/IPAddress_processing/IPDatBases/GeoLite2-City_20200901/GeoLite2-City.mmdb"

def getLoc(ip,dataset_path_of_city=dataset_path_of_city):
    '''
    本地数据库ip信息查询
    '''
    try:
        reader = geoip2.database.Reader(dataset_path_of_city)
        ip_object = reader.city(ip)
        #print(ip_object)
        if ip_object == None:
            return  {"ip地址":{}
            ,"国家":{}
            ,"省份":{}
            ,"城市":{}
            ,"纬度":{}
            ,"经度":{}}
        return  {"ip地址":ip_object.traits.ip_address
    ,"国家":ip_object.country.names
    ,"省份":ip_object.subdivisions.most_specific.names
    ,"城市":ip_object.city.names
    ,"纬度":ip_object.location.latitude
    ,"经度":ip_object.location.longitude}
    except Exception:
        return {"ip地址":{ip}
            ,"国家":{None}
            ,"省份":{None}
            ,"城市":{None}
            ,"纬度":{None}
            ,"经度":{None}}


def change_language_logic(info):
    '''
    本地数据库ip信息查询的语言选择逻辑
    '''
    if 'zh-CN' in info:
        return info['zh-CN']
    elif 'en' in info:
        return info['en']
    elif 'es' in info:
        return info['es']
    elif 'fr' in info:
        return info['fr']
    elif 'de' in info:
        return info['de']
    elif 'ru' in info:
        return info['ru']
    elif 'ja' in info:
        return info['ja']
    elif 'pt-BR' in info:
        return info['pt-BR']
    else:
        return None


def getIpv4Info(ipv4):
    '''
    整理本地查询的ip信息
    '''
    #languages = {'pt-BR', 'ru', 'de', 'zh-CN', 'es', 'en', 'fr', 'ja'}
    ip_info = getLoc(ipv4)
    ipv4 = ip_info['ip地址']
    init_countries = change_language_logic(ip_info['国家'])
    init_provinces = change_language_logic(ip_info["省份"])
    init_city = change_language_logic(ip_info["城市"])
    latitude = ip_info['纬度']
    longitude = ip_info['经度']
    return {"countries":init_countries,"provinces":init_provinces
    ,"city":init_city,"latitude":latitude,"longitude":longitude}


def ipv4_query_from_geoip2(ipv4s):
    """
    批量整理ipv4查询数据
    """
    table = {"ipv4":[],"countries_from_geoip2":[],"provinces_from_geoip2":[]
    ,"city_from_geoip2":[],"latitude_from_geoip2":[],"longitude_from_geoip2":[]}
    for ipv4 in tqdm(ipv4s,desc="ip infomation from geoip2.database ……"):
        init_info = getIpv4Info(ipv4)
        table["ipv4"].append(ipv4)
        table["countries_from_geoip2"].append(init_info["countries"])
        table["provinces_from_geoip2"].append(init_info["provinces"])
        table["city_from_geoip2"].append(init_info["city"])
        table["latitude_from_geoip2"].append(init_info["latitude"])
        table["longitude_from_geoip2"].append(init_info["longitude"])
    return table


## TODO: English info for IPv4

from urllib.request import urlopen
import json 

def ipv4_query_from_ipapi(ipv4):
    '''
    网络ip查询函数，数据来自ip-api.com
    '''
    Error_return =  {'status':None,'country':None,'countryCode':None
        ,'region':None,'regionName':None,'city':None,'zip':None
        ,'lat':None,'lon':None,'timezone':None,'isp':None
        ,'org':None,'as':None,'query':ipv4}

    t = 0
   
    try:
        url = "http://ip-api.com/json/"+ipv4
        urlObj = urlopen(url)
        pageContent = urlObj.read().decode('utf-8')
        
        # f = open(ipv4_query_log_from_ipapi,"a+")
        dict_data = json.loads(pageContent)
        
        # str_data = dict_data.__repr__()+'\n'
        # f.write(str_data)
        # f.close()
        if dict_data['status'] != 'fail':
            return dict_data
        else:
            return Error_return
    except Exception as e: 
        t += 1
        print("ipv4",ipv4,"error:",e,"t:",t)
        if t < 5:
            return ipv4_query_from_ipapi(ipv4)
        else:
            return Error_return
            

def ipv4s_query_from_ipapi(ipv4s):
    '''
    批量网络ip查询函数
    '''
    ip_query_table = {'status_from_ipapi': [], 'country_from_ipapi': [], 'countryCode_from_ipapi': [], 
    'region_from_ipapi': [], 'regionName_from_ipapi': [], 'city_from_ipapi': [], 'zip_from_ipapi': [],
     'lat_from_ipapi': [], 'lon_from_ipapi': [], 'timezone_from_ipapi': [], 'isp_from_ipapi': []
     , 'org_from_ipapi': [], 'as_from_ipapi': [],'ipv4': []}
     
    for ipv4 in tqdm(ipv4s,desc="ip infomation from ip api ……"):
        time.sleep(1)
        ip_query = ipv4_query_from_ipapi(ipv4)
        #print(ip_query,ipv4)
        ip_query_table['status_from_ipapi'].append(ip_query['status'])
        ip_query_table['country_from_ipapi'].append(ip_query['country'])
        ip_query_table['countryCode_from_ipapi'].append(ip_query['countryCode'])
        ip_query_table['region_from_ipapi'].append(ip_query['region'])
        ip_query_table['regionName_from_ipapi'].append(ip_query['regionName'])
        ip_query_table['city_from_ipapi'].append(ip_query['city'])
        ip_query_table['zip_from_ipapi'].append(ip_query['zip'])
        ip_query_table['lat_from_ipapi'].append(ip_query['lat'])
        ip_query_table['lon_from_ipapi'].append(ip_query['lon'])
        ip_query_table['timezone_from_ipapi'].append(ip_query['timezone'])
        ip_query_table['isp_from_ipapi'].append(ip_query['isp'])
        ip_query_table['org_from_ipapi'].append(ip_query['org'])
        ip_query_table['as_from_ipapi'].append(ip_query['as'])
        ip_query_table['ipv4'].append(ip_query['query'])

    ip_query_table = pd.DataFrame(ip_query_table)

    return ip_query_table


if __name__ == '__main__':  
    print(getLoc("106.55.145.106"))
    print(getIpv4Info("106.55.145.106").keys())
    print(ipv4_query_from_geoip2(["106.55.145.106","106.55.145.106"]))
    print(ipv4_query_from_ipapi('country'))
    print(ipv4s_query_from_ipapi(['country',"36.59.54.237","106.55.145.106"]))
# Out:
# {'ip地址': {'106.55.145.106'}, '国家': {None}, '省份': {None}, '城市': {None}, '纬度': {None}, '经度': {None}}
# dict_keys(['countries', 'provinces', 'city', 'latitude', 'longitude'])
# ip infomation from geoip2.database ……: 100%|██████████| 2/2 [00:00<00:00, 10727.12it/s]
# {'ipv4': ['106.55.145.106', '106.55.145.106'], 'countries_from_geoip2': [None, None], 'provinces_from_geoip2': [None, None], 'city_from_geoip2': [None, None], 'latitude_from_geoip2': [{None}, {None}], 'longitude_from_geoip2': [{None}, {None}]}
# {'status': None, 'country': None, 'countryCode': None, 'region': None, 'regionName': None, 'city': None, 'zip': None, 'lat': None, 'lon': None, 'timezone': None, 'isp': None, 'org': None, 'as': None, 'query': 'country'}
# ip infomation from ip api ……: 100%|██████████| 3/3 [00:04<00:00,  1.63s/it]
#   status_from_ipapi country_from_ipapi countryCode_from_ipapi  \
# 0              None               None                   None
# ...

# %%
import requests
import json
csv_url = "http://ip-api.com/json/"
ipv4 = "36.59.54.237"
lang = "?lang=zh-CN"
url = "{}{}{}".format(csv_url,ipv4,lang)
response = requests.get(url)
response_dict= json.loads(response.text)
response_dict
# Out:
# {'status': 'success',
#  'country': '中国',
#  'countryCode': 'CN',
#  'region': 'AH',
#  'regionName': '安徽',
#  'city': '蓉城',
#  'zip': '',
#  'lat': 30.6007,
#  'lon': 117.925,
#  'timezone': 'Asia/Shanghai',
#  'isp': 'Chinanet',
#  'org': 'Chinanet AH',
#  'as': 'AS4134 CHINANET-BACKBONE',
#  'query': '36.59.54.237'}

# %%
# 多ip查询
url = 'http://ip-api.com/batch?'
# 定义接收参数及语言，可不传
param = {
    'fields':'status,message,continent,continentCode,country,countryCode,region,regionName,city,district,zip,lat,lon,timezone,offset,currency,isp,org,as,asname,mobile,proxy,hosting,query'
	,'lang': 'zh-CN'
}
ip_list = ['118.0.3.50', '160.20.53.211', '104.67.14.136']

response = requests.post(url=url, params=param, json=ip_list)

status_dict = {
    'query':[],'status':[],'continent':[]
    ,'continentCode':[],'country':[],'countryCode':[]
    ,'region':[],'regionName':[],'city':[]
    ,'district':[],'zip':[],'lat':[],'lon':[]
    ,'timezone':[],'offset':[],'currency':[]
    ,'isp':[],'org':[],'as':[],'asname':[]
    ,'mobile':[],'proxy':[],'hosting':[]

}
result_list = json.loads(response.text)
for line in result_list:
    if 'status' in line:
        print(line)
        for key,word in line.items():
            status_dict[key].append(word)
    elif "message" in line:
        message = line["message"]
pd.DataFrame(status_dict)
# Out:
# {'status': 'success', 'continent': '亚洲', 'continentCode': 'AS', 'country': '日本', 'countryCode': 'JP', 'region': '15', 'regionName': '新潟县', 'city': 'Tsugawa', 'district': '', 'zip': '959-4401', 'lat': 37.6957, 'lon': 139.4532, 'timezone': 'Asia/Tokyo', 'offset': 32400, 'currency': 'JPY', 'isp': 'NTT Communications Corporation', 'org': 'NTT Communications Corporation', 'as': 'AS4713 NTT Communications Corporation', 'asname': 'OCN', 'mobile': False, 'proxy': False, 'hosting': False, 'query': '118.0.3.50'}
# ...

# %%
query = '118.0.3.50'
url = "{}{}{}".format('http://ip-api.com/json/'
,query
#,"?lang=zh-CN"
,'?fields=status,message,continent,continentCode,country,countryCode,region,regionName,city,district,zip,lat,lon,timezone,offset,currency,isp,org,as,asname,reverse,mobile,proxy,hosting,query'
)
result_json = json.loads(requests.get(url).text)
result_json
# Out:
# {'status': 'success',
#  'continent': 'Asia',
#  'continentCode': 'AS',
#  'country': 'Japan',
#  'countryCode': 'JP',
#  'region': '15',
#  'regionName': 'Niigata',
#  'city': 'Tsugawa',
#  'district': '',
#  'zip': '959-4401',
#  'lat': 37.6957,
#  'lon': 139.4532,
#  'timezone': 'Asia/Tokyo',
#  'offset': 32400,
#  'currency': 'JPY',
#  'isp': 'NTT Communications Corporation',
#  'org': 'NTT Communications Corporation',
#  'as': 'AS4713 NTT Communications Corporation',
#  'asname': 'OCN',
#  'reverse': 'p888050-ipngn4801niigatani.niigata.ocn.ne.jp',
#  'mobile': False,
#  'proxy': False,
#  'hosting': False,
#  'query': '118.0.3.50'}

# %%
def query_ip(ip_address):
    url = "{}{}{}".format('http://ip-api.com/json/'
    ,ip_address
    #,"?lang=zh-CN"
    ,'?fields=status,message,continent,continentCode,country,countryCode,region,regionName,city,district,zip,lat,lon,timezone,offset,currency,isp,org,as,asname,reverse,mobile,proxy,hosting,query'
    )
    result_json = json.loads(requests.get(url).text)
    return result_json
query_ip('118.0.3.50')
# Out:
# {'status': 'success',
#  'continent': 'Asia',
#  'continentCode': 'AS',
#  'country': 'Japan',
#  'countryCode': 'JP',
#  'region': '15',
#  'regionName': 'Niigata',
#  'city': 'Tsugawa',
#  'district': '',
#  'zip': '959-4401',
#  'lat': 37.6957,
#  'lon': 139.4532,
#  'timezone': 'Asia/Tokyo',
#  'offset': 32400,
#  'currency': 'JPY',
#  'isp': 'NTT Communications Corporation',
#  'org': 'NTT Communications Corporation',
#  'as': 'AS4713 NTT Communications Corporation',
#  'asname': 'OCN',
#  'reverse': 'p888050-ipngn4801niigatani.niigata.ocn.ne.jp',
#  'mobile': False,
#  'proxy': False,
#  'hosting': False,
#  'query': '118.0.3.50'}

# %%
from tqdm import tqdm

def TokenIPiters(ip_list:iter,batch=100):
    """
    分割ipv4的课迭代数据，分成每100个一组
    """
    return_dict = {}
    n = 0
    t = 0
    for ipv4 in ip_list:
        
        if n > (batch-1):
            t += 1
            n = 0
        n += 1
        if t in return_dict:
            return_dict[t].append(ipv4)
        else:
            return_dict.update({t:[ipv4]})
    # print(n)

    return return_dict


def IPAPIAReqoestsBatch(ipv4_list:list):
    """
    批量请求接口
    """
    url = 'http://ip-api.com/batch?'
    # 定义接收参数及语言，可不传
    param = {
        'fields':'status,message,continent,continentCode,country,countryCode,region,regionName,city,district,zip,lat,lon,timezone,offset,currency,isp,org,as,asname,mobile,proxy,hosting,query'
        ,'lang': 'zh-CN'
    }


    response = requests.post(url=url, params=param, json=ipv4_list)
    
    result_text = response.text
    #print(return_text)
    return json.loads(result_text)



def CounterIPv4List(ipv4s_list):
    counter_dict = {ipv4:0 for ipv4 in ipv4s_list}
    
    for ipv4 in ipv4s_list:
        counter_dict[ipv4]+=1
        
    return counter_dict

def DistinctIPList(ip_list):
    '''
    对ip列表去重
    '''
    return list(set(ip_list))

def VaildAngQueryBatchMaximum100FromIPAPI(ip_list:list):
    """
    去重并验证批量ip请求是否超过100，如未超过则开始请求
    """
    if isinstance(ip_list,list):
        pass
    else:
        return ValueError("param must a list ,plecae check you input code")
    
    #distinct_ips = DistinctIPList(ip_list)
    
    max_lenght = len(ip_list)
    if max_lenght > 100:
        return ValueError("The maximum number of IP addresses that can be processed is 100 ,\
                          \nHTTP 422 Unprocessable Entity")
    
    #print(counter_dict) 
        # 多ip查询
    return IPAPIAReqoestsBatch(ip_list)query


def ParseIPAPIQueryBatch(result_json,ipv4s_list):
    counter = CounterIPv4List(ipv4s_list)
    '''
    解析从ip-api批量查询的返回值
    '''
    
    message_dict = {"status":[],"message":[],"query":[],"counter":[]}
    status_dict = {
        'query':[],"counter":[],'status':[],'continent':[]
        ,'continentCode':[],'country':[],'countryCode':[]
        ,'region':[],'regionName':[],'city':[]
        ,'district':[],'zip':[],'lat':[],'lon':[]
        ,'timezone':[],'offset':[],'currency':[]
        ,'isp':[],'org':[],'as':[],'asname':[]
        ,'mobile':[],'proxy':[],'hosting':[]
        

    }
    for line in result_json:
        #print(line)
         # 查询不到ip地址数据的返回处理
        if "message" in line:
            for key,value in line.items():
                if key == 'query':
                    message_dict["counter"].append(counter[value])  
                message_dict[key].append(value)
            
         # 查询到ip地址数据的返回处理
        elif 'status' in line:
            for key,value in line.items():
                if key == 'query':
                    status_dict["counter"].append(counter[value])          
                status_dict[key].append(value)  

    return status_dict,message_dict

def BatchIPAPI(ipv4s_list):
    """
    从ip-api批量查询ip地址信息
    """
    distinct_ipv4s = DistinctIPList(ipv4s_list)
    token_ip_list= TokenIPiters(distinct_ipv4s)
    
    query_list = []
    step = 0
    batch_number = 0
    start_time = time.time()
    for batchNo,ipv4_list in tqdm(token_ip_list.items(),desc="{}{}{}{}".format("Batch query ipv4 addresses,step : ",str(step),"counter : ",batch_number)):
        batch_number = batchNo
        step += 1
        limit = (step % 15) == 0
        if limit:
            cut_time = step15_time-start_time
            if cut_time < 60:
                print("{}{}{}".format("The next round will have to wait ",str(60-cut_time)," seconds") )
                time.sleep(60-cut_time)
            start_time = time.time()
        step15_time=time.time()
        
        #TODO 请求主体程序    
        query_batch_maximum_100 = VaildAngQueryBatchMaximum100FromIPAPI(ipv4_list)
        
        if isinstance(query_batch_maximum_100,list):
            query_list+=query_batch_maximum_100
        else:
            print(query_batch_maximum_100)
            
    status_dict,message_dict = ParseIPAPIQueryBatch(query_list,ipv4s_list)
    
    return status_dict,message_dict


# def IPAPIBatchToCsc(paser_return):
#     """
#     整理IPapi批量请求解析得到的dict成为表格
#     """
#     status_dict,message_dict = paser_return
#     status_table = pd.DataFrame(status_dict)
#     message_table = pd.DataFrame(message_dict)

#     status_size = status_table.size
#     message_size = message_table.size

#     if (status_size != 0) and (message_size != 0):
#         return status_table,message_table
#     elif (status_size != 0) and (message_size == 0):
#         return status_table
#     elif (status_size == 0) and (message_size != 0):
#         return message_table
# xucsuq-tesda1-batkEx
lastb_table_path = os.path.expanduser('~/mingyueguan_project/LinuxDate_processing/lastb_table.csv' )   
ipv4s = list(pd.read_csv(lastb_table_path).IP)

# %%
def batch_query_ipapi(ipv4s_list):
    """
    批量查询ipv4地址的信息，每分钟上限15次
    """
    status_dict,message_dict = BatchIPAPI(ipv4s_list)
    status_table = pd.DataFrame(status_dict)
    column_name_dict = {'status': '成功',
    'message': '失败',
    'continent': '大陆名称',
    'continentCode': '大陆代码',
    'country': '国家名称',
    'countryCode': '两个字母的国家代码ISO3166-1Alpha-2',
    'region': '地区/州短代码（FIPS或ISO）',
    'regionName': '地区/州',
    'city': '城市',
    'district': '区（城市的细分）',
    'zip': '邮政编码',
    'lat': '纬度',
    'lon': '经度',
    'timezone': '时区 (tz)',
    'offset': '时区 UTC DST 偏移量（以秒为单位）',
    'currency': '本国货币',
    'isp': '网络服务商（ISP 名称）',
    'org': '组织机构名称',
    'as': 'AS编号和组织',
    'asname': 'AS的名称',
    'mobile': '移动网络（蜂窝连接）',
    'proxy': '代理',
    'hosting': '托管',
    'query': 'IP'}
    status_table.rename(columns=column_name_dict,inplace=True)
    ipv4_table = pd.DataFrame({"IP":ipv4s_list})
    full_table = pd.merge(ipv4_table,status_table,on=["IP"])
    return {"query_table":full_table,"error_dict":message_dict}

# %%
status_dict,message_dict = BatchIPAPI(ipv4s)
status_table = pd.DataFrame(status_dict)
column_name_dict = {'status': '成功',
 'message': '失败',
 'continent': '大陆名称',
 'continentCode': '大陆代码',
 'country': '国家名称',
 'countryCode': '两个字母的国家代码ISO3166-1Alpha-2',
 'region': '地区/州短代码（FIPS或ISO）',
 'regionName': '地区/州',
 'city': '城市',
 'district': '区（城市的细分）',
 'zip': '邮政编码',
 'lat': '纬度',
 'lon': '经度',
 'timezone': '时区 (tz)',
 'offset': '时区 UTC DST 偏移量（以秒为单位）',
 'currency': '本国货币',
 'isp': '网络服务商（ISP 名称）',
 'org': '组织机构名称',
 'as': 'AS编号和组织',
 'asname': 'AS的名称',
 'mobile': '移动网络（蜂窝连接）',
 'proxy': '代理',
 'hosting': '托管',
 'query': 'IP'}
status_table.rename(columns=column_name_dict,inplace=True)
ipv4_table = pd.DataFrame({"IP":ipv4s})
full_table = pd.merge(ipv4_table,status_table,on=["IP"])
# Out:
# Batch query ipv4 addresses,step : 0counter : 0:   0%|          | 0/3 [00:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-fe3656cf2f06> in <module>
# ----> 1 status_dict,message_dict = BatchIPAPI(ipv4s)
#       2 status_table = pd.DataFrame(status_dict)
#       3 column_name_dict = {'status': '成功',
#       4  'message': '失败',
#       5  'continent': '大陆名称',
#
# <ipython-input-38-f3c5a49f827e> in BatchIPAPI(ipv4s_list)
#     138
#     139         #TODO 请求主体程序
# --> 140         query_batch_maximum_100 = VaildAngQueryBatchMaximum100FromIPAPI(ipv4_list)
#     141
#     142         if isinstance(query_batch_maximum_100,list):
#
# <ipython-input-38-f3c5a49f827e> in VaildAngQueryBatchMaximum100FromIPAPI(ip_list)
#      75     #print(counter_dict)
#      76         # 多ip查询
# ---> 77     return IPAPIAReqoestsBatch(ip_list)
#      78
#      79
#
# ...

# %%
full_table
# Out:
#                     IP  counter       成功 大陆名称 大陆代码 国家名称  \
# 0       185.246.130.20    56889  success   欧洲   EU   瑞典
# 1       185.246.130.20    56889  success   欧洲   EU   瑞典
# 2       185.246.130.20    56889  success   欧洲   EU   瑞典
# 3       185.246.130.20    56889  success   欧洲   EU   瑞典
# 4       185.246.130.20    56889  success   欧洲   EU   瑞典
# ...                ...      ...      ...  ...  ...  ...
# 108115   211.43.12.240      912  success   亚洲   AS   韩国
# 108116   211.43.12.240      912  success   亚洲   AS   韩国
# 108117   211.43.12.240      912  success   亚洲   AS   韩国
# 108118   211.43.12.240      912  success   亚洲   AS   韩国
# 108119   211.43.12.240      912  success   亚洲   AS   韩国
#
#        两个字母的国家代码ISO3166-1Alpha-2 地区/州短代码（FIPS或ISO）              地区/州  \
# 0                             SE                AB  Stockholm County
# 1                             SE                AB  Stockholm County
# 2                             SE                AB  Stockholm County
# ...

# %%
from sympy import im
from tqdm import tqdm
import time
import requests
import pandas as pd
import json
import os

def token_ipv4_list(ip_list:iter,batch=100):
    """
    分割ipv4的课迭代数据，分成每100个一组
    """
    return_dict = {}
    n = 0
    t = 0
    for ipv4 in ip_list:
        
        if n > (batch-1):
            t += 1
            n = 0
        n += 1
        if t in return_dict:
            return_dict[t].append(ipv4)
        else:
            return_dict.update({t:[ipv4]})
    # print(n)

    return return_dict


def batch_requests(ipv4_list:list):
    """
    批量请求接口
    """
    url = 'http://ip-api.com/batch?'
    # 定义接收参数及语言，可不传
    param = {
        'fields':'status,message,continent,continentCode,country,countryCode,region,regionName,city,district,zip,lat,lon,timezone,offset,currency,isp,org,as,asname,mobile,proxy,hosting,query'
        ,'lang': 'zh-CN'
    }


    response = requests.post(url=url, params=param, json=ipv4_list)
    
    result_text = response.text
    #print(return_text)
    return json.loads(result_text)



def conter_ipv4_list(ipv4s_list):
    counter_dict = {ipv4:0 for ipv4 in ipv4s_list}
    
    for ipv4 in ipv4s_list:
        counter_dict[ipv4]+=1
        
    return counter_dict

def distinct_ipv4_list(ip_list):
    '''
    对ip列表去重
    '''
    return list(set(ip_list))

def vaild_and_query_maximun100(ip_list:list):
    """
    去重并验证批量ip请求是否超过100，如未超过则开始请求
    """
    if isinstance(ip_list,list):
        pass
    else:
        return ValueError("param must a list ,plecae check you input code")
    
    #distinct_ips = distinct_ipv4_list(ip_list)
    
    max_lenght = len(ip_list)
    if max_lenght > 100:
        return ValueError("The maximum number of IP addresses that can be processed is 100 ,\
                          \nHTTP 422 Unprocessable Entity")
    
    #print(counter_dict) 
        # 多ip查询
    return batch_requests(ip_list)


def parse_batch_query(result_json,ipv4s_list):
    counter = conter_ipv4_list(ipv4s_list)
    '''
    解析从ip-api批量查询的返回值
    '''
    
    message_dict = {"status":[],"message":[],"query":[],"counter":[]}
    status_dict = {
        'query':[],"counter":[],'status':[],'continent':[]
        ,'continentCode':[],'country':[],'countryCode':[]
        ,'region':[],'regionName':[],'city':[]
        ,'district':[],'zip':[],'lat':[],'lon':[]
        ,'timezone':[],'offset':[],'currency':[]
        ,'isp':[],'org':[],'as':[],'asname':[]
        ,'mobile':[],'proxy':[],'hosting':[]
        

    }
    for line in result_json:
        #print(line)
         # 查询不到ip地址数据的返回处理
        if "message" in line:
            for key,value in line.items():
                if key == 'query':
                    message_dict["counter"].append(counter[value])  
                message_dict[key].append(value)
            
         # 查询到ip地址数据的返回处理
        elif 'status' in line:
            for key,value in line.items():
                if key == 'query':
                    status_dict["counter"].append(counter[value])          
                status_dict[key].append(value)  

    return status_dict,message_dict

def batch_ipapi(ipv4s_list):
    """
    从ip-api批量查询ip地址信息
    """
    distinct_ipv4s = distinct_ipv4_list(ipv4s_list)
    token_ip_list= token_ipv4_list(distinct_ipv4s)
    
    query_list = []
    step = 0
    batch_number = 0
    start_time = time.time()
    for batchNo,ipv4_list in tqdm(token_ip_list.items(),desc="{}{}{}{}".format("Batch query ipv4 addresses,step : ",str(step),"counter : ",batch_number)):

        batch_number = batchNo
        step += 1
        limit = (step % 15) == 0
        if limit:
            cut_time = step15_time-start_time
            if cut_time < 60:
                print("{}{}{}".format("The next round will have to wait ",str(60-cut_time)," seconds") )
                time.sleep(60-cut_time)
            start_time = time.time()
        step15_time=time.time()
        
        #TODO 请求主体程序    
        query_batch_maximum_100 = vaild_and_query_maximun100(ipv4_list)
        
        if isinstance(query_batch_maximum_100,list):
            query_list+=query_batch_maximum_100
        else:
            print(query_batch_maximum_100)
            
    status_dict,message_dict = parse_batch_query(query_list,ipv4s_list)
    
    return status_dict,message_dict

def batch_query(ipv4s_list):
    """
    批量查询ipv4地址的信息，每分钟上限15次
    """
    status_dict,message_dict = batch_ipapi(ipv4s_list)
    status_table = pd.DataFrame(status_dict)
    column_name_dict = {'status': '成功',
    'message': '失败',
    'continent': '大陆名称',
    'continentCode': '大陆代码',
    'country': '国家名称',
    'countryCode': '两个字母的国家代码ISO3166-1Alpha-2',
    'region': '地区/州短代码（FIPS或ISO）',
    'regionName': '地区/州',
    'city': '城市',
    'district': '区（城市的细分）',
    'zip': '邮政编码',
    'lat': '纬度',
    'lon': '经度',
    'timezone': '时区 (tz)',
    'offset': '时区 UTC DST 偏移量（以秒为单位）',
    'currency': '本国货币',
    'isp': '网络服务商（ISP 名称）',
    'org': '组织机构名称',
    'as': 'AS编号和组织',
    'asname': 'AS的名称',
    'mobile': '移动网络（蜂窝连接）',
    'proxy': '代理',
    'hosting': '托管',
    'query': 'IP'}
    status_table.rename(columns=column_name_dict,inplace=True)
    ipv4_table = pd.DataFrame({"IP":ipv4s_list})
    full_table = pd.merge(ipv4_table,status_table,on=["IP"])
    return {"query_table":full_table,"error_dict":message_dict}




if __name__ == '__main__':
        
    lastb_table_path = os.path.expanduser('~/mingyueguan_project/LinuxDate_processing/lastb_table.csv' )   
    ipv4s = list(pd.read_csv(lastb_table_path).IP)
    batch_query(ipv4s)
# Out:
# Batch query ipv4 addresses,step : 0counter : 0:   0%|          | 0/3 [04:09<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-e386597c1c9c> in <module>
#     198     lastb_table_path = os.path.expanduser('~/mingyueguan_project/LinuxDate_processing/lastb_table.csv' )
#     199     ipv4s = list(pd.read_csv(lastb_table_path).IP)
# --> 200     batch_query(ipv4s)
#
# <ipython-input-42-e386597c1c9c> in batch_query(ipv4s_list)
#     160     批量查询ipv4地址的信息，每分钟上限15次
#     161     """
# --> 162     status_dict,message_dict = batch_ipapi(ipv4s_list)
#     163     status_table = pd.DataFrame(status_dict)
#     164     column_name_dict = {'status': '成功',
#
# <ipython-input-42-e386597c1c9c> in batch_ipapi(ipv4s_list)
#     145
#     146         #TODO 请求主体程序
# --> 147         query_batch_maximum_100 = vaild_and_query_maximun100(ipv4_list)
#     148
# ...

# %%
import time

start_time = time.time()
step = 0
for i in range(100):
    
    step += 1
    limit = (step % 15) == 0
    if limit:
        cut_time = step15_time-start_time
        if cut_time < 60:
            print("{}{}{}".format("The next round will have to wait ",str(60-cut_time)," seconds") )
            time.sleep(60-cut_time)
        start_time = time.time()
    step15_time=time.time()
    
    # 程序运行体
    time.sleep(1)
    print("step:",step)
# Out:
# step: 1
# step: 2
# step: 3
# step: 4
# step: 5
# step: 6
# step: 7
# step: 8
# step: 9
# step: 10
# step: 11
# step: 12
# step: 13
# step: 14
# The next round will have to wait 46.98014545440674 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-00e2beb13a1b> in <module>
#      11         if cut_time < 60:
#      12             print("{}{}{}".format("The next round will have to wait ",str(60-cut_time)," seconds") )
# ---> 13             time.sleep(60-cut_time)
#      14         start_time = time.time()
#      15     step15_time=time.time()
#
# KeyboardInterrupt:
